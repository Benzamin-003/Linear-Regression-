# %%
x=[1,2,3]
y=[1,2,3]

w=0
b=0

N = len(x)
alpha=0.01
epoch=1000

for i in range(epoch):
    y_pred = [w * x[j] + b for j in range(N)]
    error = [y[j] - y_pred[j] for j in range(N)]

    djw_ = [(-x[j]*(y[j]-y_pred[j]))/N for j in range(N)]
    djb_ = [(-(y[j] - y_pred[j]))/N for j in range(N)]

    djw = sum(djw_)
    djb = sum(djb_)

    w = w - alpha*djw
    b = b - alpha*djb

print(w,b)


#import matplotlib.pyplot as plt

plt.scatter(x, y, color='blue', label='Actual')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression using Cost Function')
plt.legend()
plt.show()
# Out:
# 0.9512961894220736 0.11071520925847297

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 10, 50)          
Y = 3*X + 2 + np.random.randn(50)   
w = 0.0         
b = 0.0          
alpha = 0.01     
epochs = 200     
n = len(X)

for epoch in range(epochs):
    
    Y_pred = w * X + b
    
    dw = (-2/n) * np.sum(X * (Y - Y_pred))
    db = (-2/n) * np.sum(Y - Y_pred)
    
    
    w -= alpha * dw
    b -= alpha * db
    
plt.scatter(X, Y, color='blue', label='Data Points')   
plt.plot(X, w*X + b, color='red', label='Predicted Line')  
plt.title("Linear Regression using Gradient Descent")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

print(f"\n✅ Final parameters: w={w:.4f}, b={b:.4f}")
# Out:
# ✅ Final parameters: w=3.0860, b=1.4235
